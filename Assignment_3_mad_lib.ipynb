# %%
user_requests = [
       "Please input a name" ,
       "Please input an adjective" ,
       "Please input a time" ,
       "Please input a food"
]

# name_input      = input("Please input a name")
# adjective_input = input("Please input an adjective")
# time_input      = input("Please input a time")
# food_input      = input("Please input a food")
# noun_input      = input("Please input a noun")

# user_inputs = []
user_inputs = []

# cannot do that as it does NOT know how many elements there will be, unless you specify it in advance ? 
# for i in range(len(user_requests)):
#    user_inputs[i] = input( user_requests[i] )


# To solve this, Use append ...
for i in range(len(user_requests)):
    user_inputs.append( input( user_requests[i] ) )

# ... or use list comprehension
user_inputs_2 = [input(request) for request in user_requests]


# Print these outputs to test
for j in range(len(user_inputs)):
    print(f"{user_inputs[j]}\n")


for j in range(len(user_inputs_2)):
    print(f"{user_inputs_2[j]}\n")


# Mad Lib template
mad_lib = f"\nOnce upon a time in the Mushroom Kingdom, {name1} and {name2} embarked on a {adj1} adventure \
           Their mission was to retrieve the legendary {noun1} of {adj2} power from the treacherous {noun2}."

mad_lib += f"\n\nAs they journeyed through the {adj2} landscapes of the kingdom, they encountered friendly {noun1}s and indulged in delicious {food} \
            The clock struck {time}, and the duo knew they had to reach Bowser's castle before the {time} sun set."

mad_lib += f"\n\nWith {adj1} determination, {name1} and {name2} faced challenges, solved puzzles, and finally reached the castle. \
           Inside, they confronted Bowser, who was guarding the powerful {noun1}. After an epic battle, they emerged victorious, saving the Mushroom Kingdom from {adj2} chaos."
# Out:
# martina
#
# pretty
#
# midnight
#
# pizza
#
# martina
#
# cute
#
# noon
#
# calzone

# %%
while True:

       user_welcome = input("Welcome to Mad Lib ! Fancy a nice story ? (yay/naaah)").lower()

       if user_welcome in ["yes","y","yay"]:
              user_requests = [
                     "Please input a name" ,                                 # name1
                     "Please input another name" ,                           # name2
                     "Please input an adjective (ideally positive)" ,        # adj1
                     "Please input an object" ,                              # noun1   (3)
                     "Please input another adjective (ideally negative)" ,   # adj2
                     "Please input a profession or job title" ,              # noun2
                     "Please input an animal type" ,                         # noun3 (6)
                     "Please input a food" ,                                 # food
                     "Please input a time",                                  # time  (8)
              ]
              print("Great choice ! Fill in the inputs ... \n\n")
              user_inputs_2 = [input(request) for request in user_requests]
              
              mad_lib  = f"\nOnce upon a time in the Mushroom Kingdom, {user_inputs_2[0]} and {user_inputs_2[1]} embarked on a {user_inputs_2[2]} adventure. "
              mad_lib += f"Their mission was to retrieve the legendary {user_inputs_2[3]} of {user_inputs_2[4]} power from the treacherous {user_inputs_2[5]}. "

              mad_lib += f"\n\nAs they journeyed through the {user_inputs_2[4]} landscapes of the kingdom, they encountered friendly {user_inputs_2[6]}s and indulged in delicious {user_inputs_2[7]}. "
              mad_lib += f"The clock struck {user_inputs_2[8]}, and the duo knew they had to reach Bowser's castle before the {user_inputs_2[8]} sun set. "

              mad_lib += f"\n\nWith {user_inputs_2[2]} determination, {user_inputs_2[0]} and {user_inputs_2[1]} faced challenges, solved puzzles, and finally reached the castle. "
              mad_lib += f"Inside, they confronted Bowser, who was guarding the powerful {user_inputs_2[3]}. After an epic battle, they emerged victorious, saving the Mushroom Kingdom from {user_inputs_2[4]} chaos."
           
              print("and there goes your story ...\n\n")
              print(mad_lib)
              
       elif user_welcome in ["no","n","naaah"]:
              print("You are missing out. Enjoy the rest of your day")
              break
       else:
              print("Say that again ? Ideally with 'yes' or 'no'")
              continue
       
         
user_requests = [
       "Please input a name" ,                                 # name1
       "Please input another name" ,                           # name2
       "Please input an adjective (ideally positive)" ,        # adj1
       "Please input an object" ,                              # noun1   (3)
       "Please input another adjective (ideally negative)" ,   # adj2
       "Please input a profession or job title" ,              # noun2
       "Please input an animal type" ,                         # noun3 (6)
       "Please input a food" ,                                 # food
       "Please input a time",                                  # time  (8)
]

# range(0,4)

# ... or use list comprehension
user_inputs_2 = [input(request) for request in user_requests]


# mad_lib = f"\nOnce upon a time in the Mushroom Kingdom, {name1} and {name2} embarked on a {adj1} adventure. Their mission was to retrieve the legendary {noun1} of {adj2}
# power from the treacherous {noun2}."

# mad_lib += f"\n\nAs they journeyed through the {adj2} landscapes of the kingdom, they encountered friendly {noun1}s and indulged in delicious {food}. 
# The clock struck {time}, and the duo knew they had to reach Bowser's castle before the {time} sun set."

# mad_lib += f"\n\nWith {adj1} determination, {name1} and {name2} faced challenges, solved puzzles, and finally reached the castle. Inside, they confronted Bowser, who was guarding the powerful {noun1}. 
# After an epic battle, they emerged victorious, saving the Mushroom Kingdom from {adj2} chaos."


# Mad Lib template
mad_lib  = f"\nOnce upon a time in the Mushroom Kingdom, {user_inputs_2[0]} and {user_inputs_2[1]} embarked on a {user_inputs_2[2]} adventure. "
mad_lib += f"Their mission was to retrieve the legendary {user_inputs_2[3]} of {user_inputs_2[4]} power from the treacherous {user_inputs_2[5]}. "

mad_lib += f"\n\nAs they journeyed through the {user_inputs_2[4]} landscapes of the kingdom, they encountered friendly {user_inputs_2[6]}s and indulged in delicious {user_inputs_2[7]}. "
mad_lib += f"The clock struck {user_inputs_2[8]}, and the duo knew they had to reach Bowser's castle before the {user_inputs_2[8]} sun set. "

mad_lib += f"\n\nWith {user_inputs_2[2]} determination, {user_inputs_2[0]} and {user_inputs_2[1]} faced challenges, solved puzzles, and finally reached the castle. "
mad_lib += f"Inside, they confronted Bowser, who was guarding the powerful {user_inputs_2[3]}. After an epic battle, they emerged victorious, saving the Mushroom Kingdom from {user_inputs_2[4]} chaos."
           

print(mad_lib)
# Out:
# Once upon a time in the Mushroom Kingdom, martina and matt embarked on a poisonous adventure. Their mission was to retrieve the legendary glass of sunny power from the treacherous data scientist.
#
# As they journeyed through the sunny landscapes of the kingdom, they encountered friendly octopuss and indulged in delicious pizza. The clock struck noon, and the duo knew they had to reach Bowser's castle before the noon sun set.
#
# With poisonous determination, martina and matt faced challenges, solved puzzles, and finally reached the castle. Inside, they confronted Bowser, who was guarding the powerful glass. After an epic battle, they emerged victorious, saving the Mushroom Kingdom from sunny chaos.

# %%
# verify for empty strings and error message (still using list comprehrension)


while True:
       
       user_welcome = input("Welcome to Mad Lib ! Fancy a nice story ? (yay/naaah)").lower()


       if user_welcome in ["yes","y","yay"]:
              user_requests = [
                     "Please input a name" ,                                 # name1
                     "Please input another name" ,                           # name2
                     "Please input an adjective (ideally positive)" ,        # adj1
                     "Please input an object" ,                              # noun1   (3)
                     "Please input another adjective (ideally negative)" ,   # adj2
                     "Please input a profession or job title" ,              # noun2
                     "Please input an animal type" ,                         # noun3 (6)
                     "Please input a food" ,                                 # food
                     "Please input a time",                                  # time  (8)
              ]
              print("Great choice ! Fill in the inputs ... \n\n")
              user_inputs_2 = [input(request) for request in user_requests]
              
              mad_lib  = f"\nOnce upon a time in the Mushroom Kingdom, {user_inputs_2[0]} and {user_inputs_2[1]} embarked on a {user_inputs_2[2]} adventure. "
              mad_lib += f"Their mission was to retrieve the legendary {user_inputs_2[3]} of {user_inputs_2[4]} power from the treacherous {user_inputs_2[5]}. "

              mad_lib += f"\n\nAs they journeyed through the {user_inputs_2[4]} landscapes of the kingdom, they encountered friendly {user_inputs_2[6]}s and indulged in delicious {user_inputs_2[7]}. "
              mad_lib += f"The clock struck {user_inputs_2[8]}, and the duo knew they had to reach Bowser's castle before the {user_inputs_2[8]} sun set. "

              mad_lib += f"\n\nWith {user_inputs_2[2]} determination, {user_inputs_2[0]} and {user_inputs_2[1]} faced challenges, solved puzzles, and finally reached the castle. "
              mad_lib += f"Inside, they confronted Bowser, who was guarding the powerful {user_inputs_2[3]}. After an epic battle, they emerged victorious, saving the Mushroom Kingdom from {user_inputs_2[4]} chaos."
           
              print("and there goes your story ...\n\n")
              print(mad_lib)
              break
              
       elif user_welcome in ["no","n","naaah"]:
              print("You are missing out. Enjoy the rest of your day")
              break
       else:
              print("Say that again ? Ideally with 'yes' or 'no'")
              continue
# Out:
# Say that again ? Ideally with 'yes' or 'no'
# Great choice ! Fill in the inputs ...
#
#
# and there goes your story ...
#
#
#
# Once upon a time in the Mushroom Kingdom, q and  embarked on a dd adventure. Their mission was to retrieve the legendary ef of  power from the treacherous wd.
#
# As they journeyed through the  landscapes of the kingdom, they encountered friendly fres and indulged in delicious sad. The clock struck ewf, and the duo knew they had to reach Bowser's castle before the ewf sun set.
#
# With dd determination, q and  faced challenges, solved puzzles, and finally reached the castle. Inside, they confronted Bowser, who was guarding the powerful ef. After an epic battle, they emerged victorious, saving the Mushroom Kingdom from  chaos.

# %%
# include 3 stories, to be randomly chosen ?

while True:
       
    user_welcome = input("Welcome to Mad Lib ! Fancy a nice story ? (yay/naaah)").lower()

    # 1st and Main part of the program
    if user_welcome in ["yes","y","yay"]:
        
        # STEP 1 : Prepare variables : (a) list of requests to ask the user and (b) the list to contain them.
        user_requests = [
                     "Please input a name" ,                            # name1
                     "and now another name" ,                           # name2
                     "What about an adjective (ideally positively connotated)" ,      # adj1
                     "Doing great so far ! Now an object please " ,                   # noun1   (3)
                     "And another adjective (ideally negative this time)" ,   # adj2
                     "The profession or job title of your dream" ,            # noun2
                     "Your fave animal ?" ,                         # noun3 (6)
                     "Food you like the most ... " ,                # food
                     "and the time at which you eat it",            # time  (8)
        ]
    
        print("Great choice ! Fill in the inputs now ... \n\n")
              #user_inputs_2 = [input(request) for request in user_requests]
              
        user_inputs_2 = []
        
        
        # STEP 2 Prompt the inputs to the user, verify they actually input something, store it in the list "user_input_2" for later use          
        for request in user_requests:
            user_preinput = input(request)
            
            while not user_preinput.strip():
                print("Enter something at least !")
                user_preinput = input(request)
            
            user_inputs_2.append(user_preinput)
        
        
        # STEP 3 : Construct the strings that compose the story and display the story
        mad_lib  = f"\nOnce upon a time in the Mushroom Kingdom, {user_inputs_2[0]} and {user_inputs_2[1]} embarked on a {user_inputs_2[2]} adventure. "
        mad_lib += f"Their mission was to retrieve the legendary {user_inputs_2[3]} of {user_inputs_2[4]} power from the treacherous {user_inputs_2[5]}. "

        mad_lib += f"\nAs they journeyed through the {user_inputs_2[4]} landscapes of the kingdom, they encountered friendly {user_inputs_2[6]}s and indulged in delicious {user_inputs_2[7]}. "
        mad_lib += f"The clock struck {user_inputs_2[8]}, and the duo knew they had to reach Bowser's castle before the {user_inputs_2[8]} sun set. "

        mad_lib += f"\nWith {user_inputs_2[2]} determination, {user_inputs_2[0]} and {user_inputs_2[1]} faced challenges, solved puzzles, and finally reached the castle. "
        mad_lib += f"Inside, they confronted Bowser, who was guarding the powerful {user_inputs_2[3]}. After an epic battle, they emerged victorious, saving the Mushroom Kingdom from {user_inputs_2[4]} chaos."
           
        print("and there goes your story ...\n\n")
        print(mad_lib)
        break
    
    #  User refuses to play and exits game from the start          
    elif user_welcome in ["no","n","naaah"]:
        print("You are missing out. Enjoy the rest of your day")
        break
    
    # Forces user to input "yes" or "no"
    else:
        print("Say that again ? Ideally with 'yes' or 'no'")
        continue
# Out:
# Great choice ! Fill in the inputs now ...
#
#
# Enter something at least !
# Enter something at least !
# Enter something at least !
# Enter something at least !
# Enter something at least !
# and there goes your story ...
#
#
#
# Once upon a time in the Mushroom Kingdom, Martina and Arin embarked on a great adventure. Their mission was to retrieve the legendary guitar of idiot power from the treacherous data scientist.
# As they journeyed through the idiot landscapes of the kingdom, they encountered friendly rhinos and indulged in delicious pizza. The clock struck 7.30, and the duo knew they had to reach Bowser's castle before the 7.30 sun set.
# With great determination, Martina and Arin faced challenges, solved puzzles, and finally reached the castle. Inside, they confronted Bowser, who was guarding the powerful guitar. After an epic battle, they emerged victorious, saving the Mushroom Kingdom from idiot chaos.
